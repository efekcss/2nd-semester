# %% [markdown]
# # 1. Tek bir sınıfı içe aktarma

# %%
from  car import  Car

# %%
my_new_car =Car("audi","a6", 2017)

# %%
my_new_car.get_description()
# Out:
# '2017 audi a6'

# %%
my_new_car.orometer_reading = 25

# %%
my_new_car.read_odometer()
# Out:
# This car has 25 miles on it

# %% [markdown]
# # 2. Bir modülde birden fazla sınıfın saklanması

# %%
from car import ElectricCar

# %%
my_car = ElectricCar("tesa", "model's", 2019)

# %%
my_car.get_description()
# Out:
# "2019 tesa model's"

# %%
my_car.battery.describe_battery()
# Out:
# This car has a 70 -kwh battery

# %%
my_car.battery.get_range()
# Out:
# This kind of car can go approximately 300 miles on a full charge

# %% [markdown]
# # 3. Bir modülde birden çok sınıfı içe aktarma

# %%
from car import Car, ElectricCar 

my_beetle = Car("Volkswagen",'beetle',2019)
print(my_beetle.get_description())

my_tesla = ElectricCar('tesla','roadster',2019)
print(my_tesla.get_description())
# Out:
# 2019 Volkswagen beetle
# 2019 tesla roadster

# %% [markdown]
# # 4. Bütün modülü içe aktarma

# %%
import car  

my_beetle = car.Car("Volkswagen",'beetle',2019)
print(my_beetle.get_description())

my_tesla = car.ElectricCar('tesla','roadster',2019)
print(my_tesla.get_description())
# Out:
# 2019 Volkswagen beetle
# 2019 tesla roadster

# %% [markdown]
# # 5. Modüldeki tüm sınıfları içe aktarma

# %%
from module_name import *

# ya da

from module_name.class_name import *
