# %%
a = 3.0
b = 3

# %%
a == b
# Out:
# True

# %%
a is b
# Out:
# False

# %%
c = 256
d = 256

# %%
c is d
# Out:
# True

# %%
c == d
# Out:
# True

# %%
a = "hello"
b = "hello"
c = "hello world"[:5]
d = "hello!"

# %%
a == b
# Out:
# True

# %%
a is b
# Out:
# True

# %%
a == c
# Out:
# True

# %%
a is c
# Out:
# False

# %%
#  slicing d to exclude the last character produces "hello", so a and d[:-1] have the same value.
a == d[:-1]
# Out:
# True

# %%
# slicing d produces a new object in memory, so a and d[:-1] are different objects.
a is d[:-1]
# Out:
# False
